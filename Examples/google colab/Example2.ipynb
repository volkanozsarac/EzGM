# %% [markdown]
# # Building Code Based Record Selection
# Created on: 26/08/2021
#
# Updated on: 06/07/2023
#
# Author: Volkan Ozsarac
#
# Affiliation: EUCENTRE, European Centre for Training and Research in Earthquake Engineering
#
# PhD, Seismic Risk Specialist, Structural Engineer
#
# email:  ozsarac.volkan@eucentre.it

# %% [markdown]
# ## Package installation on Google Colaboratory

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory to the location of notebook
# %cd /content/drive/My Drive/Colab Notebooks/EzGM/notebooks
# Install EzGM
# !pip install --upgrade pip
# !pip install git+https://github.com/volkanozsarac/EzGM.git
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/EzGM/notebooks
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.1.2)
# Collecting git+https://github.com/volkanozsarac/EzGM.git
#   Cloning https://github.com/volkanozsarac/EzGM.git to /tmp/pip-req-build-xw25oa9o
#   Running command git clone --filter=blob:none --quiet https://github.com/volkanozsarac/EzGM.git /tmp/pip-req-build-xw25oa9o
#   Resolved https://github.com/volkanozsarac/EzGM.git to commit c33ab0325a3bea1535681f8b52710384403fbd1d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting openquake.engine>=3.14.0 (from EzGM==1.7.0.0)
#   Downloading openquake.engine-3.16.4-py3-none-any.whl (49.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 17.3 MB/s eta 0:00:00
# Collecting selenium==4.2.0 (from EzGM==1.7.0.0)
#   Downloading selenium-4.2.0-py3-none-any.whl (983 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 63.1 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.55.1 in /usr/local/lib/python3.10/dist-packages (from EzGM==1.7.0.0) (0.56.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from EzGM==1.7.0.0) (4.11.2)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from EzGM==1.7.0.0) (4.65.0)
# Requirement already satisfied: h5py>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from EzGM==1.7.0.0) (3.8.0)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from EzGM==1.7.0.0) (3.7.1)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium==4.2.0->EzGM==1.7.0.0) (1.26.16)
# Collecting trio~=0.17 (from selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading trio-0.22.1-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 34.2 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->EzGM==1.7.0.0) (2.4.1)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from h5py>=3.1.0->EzGM==1.7.0.0) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.2->EzGM==1.7.0.0) (2.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.1->EzGM==1.7.0.0) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.1->EzGM==1.7.0.0) (67.7.2)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (1.10.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (1.5.3)
# Requirement already satisfied: pyzmq>=19.0 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (23.2.1)
# Requirement already satisfied: psutil>=2.0 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (5.9.5)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (2.0.1)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (0.16)
# Requirement already satisfied: decorator>=4.3 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (4.4.2)
# Collecting django>=3.2 (from openquake.engine>=3.14.0->EzGM==1.7.0.0)
#   Downloading Django-4.2.3-py3-none-any.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 102.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (2.27.1)
# Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (0.10.2)
# Requirement already satisfied: pyproj>=1.9 in /usr/local/lib/python3.10/dist-packages (from openquake.engine>=3.14.0->EzGM==1.7.0.0) (3.6.0)
# Collecting asgiref<4,>=3.6.0 (from django>=3.2->openquake.engine>=3.14.0->EzGM==1.7.0.0)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from django>=3.2->openquake.engine>=3.14.0->EzGM==1.7.0.0) (0.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->openquake.engine>=3.14.0->EzGM==1.7.0.0) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=1.9->openquake.engine>=3.14.0->EzGM==1.7.0.0) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->EzGM==1.7.0.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openquake.engine>=3.14.0->EzGM==1.7.0.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openquake.engine>=3.14.0->EzGM==1.7.0.0) (3.4)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0->EzGM==1.7.0.0) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0->EzGM==1.7.0.0) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0->EzGM==1.7.0.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.2.0->EzGM==1.7.0.0) (1.1.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pyOpenSSL>=0.14 (from urllib3[secure,socks]~=1.26->selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.3 MB/s eta 0:00:00
# Collecting cryptography>=1.3.4 (from urllib3[secure,socks]~=1.26->selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading cryptography-41.0.1-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 53.2 MB/s eta 0:00:00
# Collecting urllib3-secure-extra (from urllib3[secure,socks]~=1.26->selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl (1.4 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[secure,socks]~=1.26->selenium==4.2.0->EzGM==1.7.0.0) (1.7.1)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from asgiref<4,>=3.6.0->django>=3.2->openquake.engine>=3.14.0->EzGM==1.7.0.0) (4.6.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium==4.2.0->EzGM==1.7.0.0) (1.15.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium==4.2.0->EzGM==1.7.0.0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium==4.2.0->EzGM==1.7.0.0) (2.21)
# Building wheels for collected packages: EzGM
#   Building wheel for EzGM (pyproject.toml) ... done
#   Created wheel for EzGM: filename=EzGM-1.7.0.0-py3-none-any.whl size=88483 sha256=ecdd01b9a194abe8cdfc36721d504a3455529c0302c0a1b0ae84b6135ea66bbc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_6a15akc/wheels/d5/60/a4/d7c95c5198b7478101d98dc7615b3ce56414a894171acfeeee
# Successfully built EzGM
# Installing collected packages: urllib3-secure-extra, outcome, h11, asgiref, wsproto, trio, django, cryptography, trio-websocket, pyOpenSSL, openquake.engine, selenium, EzGM
# Successfully installed EzGM-1.7.0.0 asgiref-3.7.2 cryptography-41.0.1 django-4.2.3 h11-0.14.0 openquake.engine-3.16.4 outcome-1.2.0 pyOpenSSL-23.2.0 selenium-4.2.0 trio-0.22.1 trio-websocket-0.10.3 urllib3-secure-extra-0.1.0 wsproto-1.2.0

# %%
from EzGM.selection import CodeSpectrum
from EzGM.utility import run_time
from time import time
import os

# %%
# Acquire the run start time
start_time = time()

# Path to user-defined target spectrum
parent_path = os.path.dirname(os.path.realpath(""))
target_path = os.path.join(parent_path,'input files','Target_Spectrum.txt')

# if target_path=none, target spectrum is generated based on site parameters, and specified code
# Comment the next line if you want to use the user-defined spectrum.
target_path=None

# %% [markdown]
# ## 1) Initialize the code_spectrum object for record selection

# %%
# Set the record selection settings at this stage
spec = CodeSpectrum(database='NGA_W2', output_directory='Outputs', target_path=target_path, num_records=11, num_components=2,
            mag_limits=[6.5, 8], vs30_limits=[200, 700], rjb_limits=[0, 20], mech_limits=None, selection_algorithm=1,
            max_scale_factor=2.5, max_rec_per_event=3)

# %% [markdown]
# ## 2) Select the ground motions
# ### 2a) According to TBEC 2018 (Turkish Building Earthquake Code)

# %%
spec.select_tbec2018(lat=41.0582, long=29.00951, dd_level=2, site_class='ZC', predominant_period=1)

# selected records can be plotted at this stage
spec.plot(save=1, show=1)
# Out:
# TBEC 2018 based ground motion record selection and amplitude scaling are finished...

# %% [markdown]
# ### 2b) According to ASCE 7-16 (Minimum Design Loads and Associated Criteria for Buildings and Other Structures, 2016)

# %%
spec.select_asce7_16(lat=34, long=-118, risk_cat='II', site_class='C', fundamental_periods = [1, 1], lower_bound_period = None, upper_bound_period = None)

# selected records can be plotted at this stage
spec.plot(save=1, show=1)
# Out:
# ASCE 7-16 based ground motion record selection and amplitude scaling are finished...

# %% [markdown]
# ### 2c) According to EC8 Part 1 (Eurocode 8 Part 1)

# %%
spec.select_ec8_part1(ag=0.2, xi=0.05, importance_class='II', target_type='Type1', site_class='C', predominant_period=1)

# selected records can be plotted at this stage
spec.plot(save=1, show=1)
# Out:
# EC8 - Part 1 based ground motion record selection and amplitude scaling are finished...

# %% [markdown]
# ### 4) First the records can be downloaded via download method. If database='NGA_W2' the preferred browser to execute the method should be provided. In this case records will be retrieved from [http://ngawest2.berkeley.edu/]. If you already have record database elsewhere you can ignore and comment this part

# %%
# You should enter correct credentials to download the records
spec.download(username='example_username@email.com', password='example_password123456', browser='chrome')
# Out:
# Started executing download method to retrieve selected records from https://ngawest2.berkeley.edu
# Getting the webdriver to use...
# Webdriver is obtained successfully.
# Signing in with credentials...
# Signed in successfully.
# Listing the Records...
# Search was successfully created. Please allow time to render the graphics.
# You are downloading the UNSCALED, PROCESSED, AS-RECORDED (unrotated) displacement, velocity and acceleration trace files. The scale factors determined using the on-line tool are given in the csv file accompanying the trace files! The users of the PEER-NGA databases, flatfiles, models and reports are requested to acknowledge the Pacific Earthquake Engineering Research Center (PEER) in their work and publications.
# Please allow a few seconds of apparent inactivity for the download to complete. The wait time depends on the number of records being downloaded and the network speed. Wait until your browser indicates that it has completed the download!
# Finishing in 4 ...
# Finishing in 3 ...
# Finishing in 2 ...
# Finishing in 1 ...
# Finishing in 0 ...
# Downloaded files are located in
# C:\Users\Volkan\Documents\GitHub\EzGM\Examples\binder\Outputs\unscaled_records_2023_7_6_11_6_26_3_187_0.zip

# %% [markdown]
# ### 5) If you have records already inside zip_parent_path\database.zip\database or downloaded records, write whatever you want, the object itself, selected and scaled time histories

# %%
spec.write(object=1, records=1, zip_parent_path='')
# Out:
# Finished writing process, the files are located in
# C:\Users\Volkan\Documents\GitHub\EzGM\Examples\binder\Outputs

# %%
# Calculate the total time passed
run_time(start_time)
# Out:
# Run time: 0 hours: 0 minutes: 56.23 seconds
